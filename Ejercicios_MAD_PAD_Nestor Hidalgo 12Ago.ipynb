# %% [markdown]
# #Ejercicios clase python 12Agosto2026
# ##Néstor Fabian Hidalgo

# %% [markdown]
# ##Ejercicio Diapositiva 3

# %%
leer saldo

Si retiro <= saldo
saldo = saldo - retiro
Si no
mostrar error
# Out:
#   File "/tmp/ipykernel_2443/794854576.py", line 1
#     leer saldo
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##Ejercicio Diapositiva 54

# %%
precio = 100000
iva = precio * 0.19
total = precio + iva
print ("Total: ", total)
print (f'Totalito: {total}')

if total >100000:
  print ('Compra de alto valor')
else:
  print ('Compra de bajo valor')
# Out:
# Total:  119000.0
# Totalito: 119000.0
# Compra de alto valor

# %% [markdown]
# ##Ejercicio Diapositiva 5

# %%
edad = 21
if edad >=18:
  print ('Mayor de edad')
else:
  print ('Menor')
# Out:
# Mayor de edad

# %% [markdown]
# ##Ejercicio Diapositiva 6

# %%
nota = 2.99
if nota >=3:
  print ('Aprobado')
else:
  print ('perdio papa')
# Out:
# perdio papa

# %% [markdown]
# ##Ejercicio Diapositiva 7

# %%
# Opción incorrecta
nota = 4.7
if nota >= 3.0:
  print ('Aprobado')
elif nota >= 4.5:
  print ('Excelente')

#Opción corregida
nota = 2
if nota >= 4.5:
  print ('Excelente')
elif nota >= 3.0:
  print ('Aprobado')
else:
  print ('Perdiste el año')
# Out:
# Aprobado
# Perdiste el año

# %% [markdown]
# ##Ejecicio Diapositiva 8

# %%
nota = 2.8
if nota >= 4.5:
  print ('Excelente')
elif nota >=4.0:
  print ('Muy buen desempeño')
elif nota >=3.0:
  print ('Aprobado')
else:
    print ('No Aprobado, perdiste, jejeje')
# Out:
# No Aprobado, perdiste, jejeje

# %% [markdown]
# ##Ejercicio Diapositiva 9

# %%
usuario_activo = False
tiene_permiso = False

if usuario_activo and tiene_permiso:
  print ('Welcome')
else:
    print ('Sorry no puedes pasar')
# Out:
# Sorry no puedes pasar

# %% [markdown]
# # Diapositiva 10

# %%
#Sintaxis identación CORRECTA
if nota >=3.0:
  print ('Aprobado')
else:
    print ('perdistess')

#Sintaxis identación incorrecta
if nota >=3.0:
print ('Aprobado')
else:
print ('perdistess')
# Out:
#   File "/tmp/ipykernel_2443/798376947.py", line 9
#     print ('Aprobado')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 8

# %% [markdown]
# #DIAPOSITIVA 11

# %%
for numero in range (1,6):
  print (numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ##Diapositiva 12

# %%
for numero in range (1, 11):
  if numero %2==0:
    print (numero, "es par")
# Out:
# 2 es par
# 4 es par
# 6 es par
# 8 es par
# 10 es par

# %% [markdown]
# ##Diapositiva 13 While

# %%
numero = 1
while numero <= 5:
  print (numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ##Diapositiva 14 Intentos contraseña con While

# %%
clave_correcta = "python123"
clave= ""

while clave != clave_correcta:
  clave = input ('Ingrese la contraseña: ')

print ("Acceso Autorizado")
# Out:
# Ingrese la contraseña: 111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_549/1423140029.py in <cell line: 0>()
#       3
#       4 while clave != clave_correcta:
# ----> 5   clave = input ('Ingrese la contraseña: ')
#       6
#       7 print ("Acceso Autorizado")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# ##Diapositiva 15 for vs while

# %%
#for
for i in range (5):
  print (i)

#while
numero = 1
while numero <= 5:
  print (numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ##Diapositiva 16 predecir antes de ejecutar

# %%
for numero  in range (1,8):
  if numero <3:
    print (numero, "A")

  elif numero <6:
    print (numero, "B")

  else:
    print (numero, "C")
# Out:
# 1 A
# 2 A
# 3 B
# 4 B
# 5 B
# 6 C
# 7 C

# %% [markdown]
# ##Diapositiva 17 ejercicio for - temperatura

# %%
for i in range (5):
  t = float (input ('Temperatura: '))

  if t < 18:
    print ('Temperatura baja')
  elif t <= 25:
      print ('Temperatura normal')
  else:
      print('Temperatura Alta')
# Out:
# Temperatura: 30
# Temperatura Alta
# Temperatura: 5
# Temperatura baja
# Temperatura: 6
# Temperatura baja
# Temperatura: 8
# Temperatura baja
# Temperatura: 66
# Temperatura Alta

# %% [markdown]
# ##Diapositiva 18 de seudo a Python

# %%
nota = float(input("nota"))

if nota >= 3.0:
  print ("Aprobado")
else:
  print ("Te jodistes")
# Out:
# nota1
# Te jodistes
