# %% [markdown]
# ## Ejercicios de práctica Fundamentos Python (1) - Nestor Hidalgo - 13Agosto

# %% [markdown]
# ## 1 Completa la condición para mostrar “Mayor de edad” cuando la variable edad sea mayor o igual a 18.

# %%
edad = 20
if edad >=18:
 print("Mayor de edad")
# Out:
# Mayor de edad

# %% [markdown]
# ##2 Agrega la ruta alternativa
# Completa la estructura para clasificar una temperatura como “Alta” si supera 30 grados y
# “Normal” en caso contrario.

# %%
temperatura = 32
if temperatura > 30:
 print("Alta")
else:
 print("Normal")
# Out:
# Alta

# %% [markdown]
# ## 3 Predice la salida
# Sin ejecutar, escribe exactamente qué imprimirá el programa.

# %%
numero = 8
if numero % 2 == 0:
 print("Par")
else:
 print("Impar")
#Ejeciccio evalua si el numero ingresado es par
# Out:
# Par

# %% [markdown]
# ## B. Múltiples condiciones
# if / elif / else y orden de evaluación
#
# 4. Completa la clasificación
# Agrega las dos expresiones faltantes para clasificar la nota.

# %%
nota = 2.2
if nota >= 4.5:
 print("Excelente")
elif nota >= 4.0:
 print("Muy buen desempeño")
elif nota >=3.0:
 print("Aprobado")
else:
 print("No aprobado")
# Out:
# No aprobado

# %% [markdown]
# 5. Corrige el orden
# El programa pretende mostrar “Excelente” para notas de 4.5 o más. Reescribe únicamente el
# bloque condicional en el orden correcto.

# %%
nota = 3
if nota >= 4.5:
 print("Excelente")
elif nota >= 3.0:
 print("Aprobado")
# Out:
# Aprobado

# %% [markdown]
# 6. Traza la ejecución
# Escribe la salida para valor = 12. Después indica cuál condición fue la primera verdadera.

# %%
valor = 4
if valor < 5:
 print("A")
elif valor < 10:
 print("B")
elif valor < 15:
 print("C")
else:
 print("D")

 # La condición para 12 es la "C" porque está en la condición de menor a 15
# Out:
# A

# %% [markdown]
# ##C. Operadores lógicos
# Construye condiciones con and, or y not
#
# 7. Acceso con dos requisitos
# Completa el operador lógico para permitir acceso solo cuando ambas variables sean verdaderas.

# %%
usuario_activo = True
tiene_permiso = True
if usuario_activo and tiene_permiso:
 print("Acceso permitido")
else:
 print("Acceso denegado")
# Out:
# Acceso permitido

# %% [markdown]
# ## 8. Dos rutas válidas
# Completa la condición: se permite continuar si existe correo válido o teléfono válido.

# %%
correo_valido = False
telefono_valido = True
if correo_valido or telefono_valido:
 print("Continuar registro")
else:
 print("Faltan datos de contacto")
# Out:
# Continuar registro

# %% [markdown]
# ## 9. Usa negación
# Completa la condición usando not para mostrar el mensaje solo si la cuenta NO está
# bloqueada.

# %%
cuenta_bloqueada = False
if not cuenta_bloqueada:
 print("Puede operar")
# Out:
# Puede operar

# %% [markdown]
# ## D. Estructura repetitiva for
# 10. Recorrer rangos y controlar iteraciones
#
# Recorre del 1 al 5
# Completa range() para imprimir los valores 1, 2, 3, 4 y 5.

# %%
for numero in range (1,6):
  print (numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 11. Recorre con paso
# Completa range() para imprimir 2, 4, 6, 8 y 10.

# %%
for numero in range(2, 11, 2):
 print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## 12. Predice el acumulado
# Sin ejecutar, determina el valor final de suma.

# %%
suma = 0
for i in range(1, 4):
 suma = suma + i
print(suma)
# Out:
# 6

# %% [markdown]
# 13. E. Estructura repetitiva while
# Repetir mientras una condición permanezca verdadera
# Completa el contador
# Completa la condición y la actualización para imprimir los números del 1 al 5.

# %%
numero = 1
while numero <=5:
 print(numero)
 numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 14 Encuentra el ciclo infinito
# El siguiente programa nunca termina. Corrige solo la línea que falta dentro del ciclo.

# %%
numero = 1
while numero <= 5:
 print(numero)
 numero += numero
# Out:
# 1
# 2
# 4

# %% [markdown]
# ### Solución alternativa con bucle `for`
#
# Este mismo ejercicio se puede resolver de manera más concisa usando un bucle `for`:

# %%
for numero in range(1, 6):
  print(numero)
