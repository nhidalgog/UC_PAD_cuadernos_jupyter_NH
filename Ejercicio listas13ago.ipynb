# %% [markdown]
# ejercicio

# %%
notas = [3.5, 4.2]
notas.append(2.8)
print (notas)
# Out:
# [3.5, 4.2, 2.8]

# %%
nombres = ['Ana', 'Juan', 'María', 'Pedro']

for indice, nombre in enumerate(nombres):
    print(f"El nombre en la posición {indice} es {nombre}")

# %% [markdown]
# Ejercicio Diccionario + Listas

# %%
datos = {"a": [1,2], "b": [3]}

datos ["a"].append (9)
datos ["c"] = [4,5]

for clave, lista in datos.items():
  print (clave, len(lista))
  print (datos)
# Out:
# a 3
# {'a': [1, 2, 9], 'b': [3], 'c': [4, 5]}
# b 1
# {'a': [1, 2, 9], 'b': [3], 'c': [4, 5]}
# c 2
# {'a': [1, 2, 9], 'b': [3], 'c': [4, 5]}

# %% [markdown]
# Ejercicio for de notas

# %%
notas = [3.5, 4.2, 2.8]
suma = 0

for n in notas :
  suma = suma + n

  print (suma /3)
# Out:
# 1.1666666666666667
# 2.566666666666667
# 3.5
