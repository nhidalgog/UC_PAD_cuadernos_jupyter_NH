# %% [markdown]
# #ANALISIS EXPLORATORIO DE DATOS ALMACEN NANITOS
#
# ##Alumnos: Yibely Estefany Herrera Velasquez y Néstor Fabian Hidalgo González

# %% [markdown]
# #INTRODUCCIÓN
# En este proyecto se realiza un analis sobre una base de ventas de un almacen de ropa y accesorios para Bebes. con base en esta información se busca identificar los días y horas de mayor afluencia de público con el fin de implementar estrategias que den una mayor percepción del servicio a los clientes.

# %% [markdown]
# ## Origen de los datos
# Los datos provienen del sistema de ventas de la tienda Nanitos, esta base de datos contine información del último trimestre de 2026, contiene un total de 3.709 registros.
# ###
# ruta del archivo: /content/drive/MyDrive/Maestria/Programación Python/Proyecto_PÁD/reporte_de_ventas_nanitos_may_a_jul_2026.csv

# %% [markdown]
# ##Importar librerias

# %%
#En este notebook se va a trabajar con las siguientes librerías.
import pandas as pd
import numpy as np

# %% [markdown]
# ##Carga de Datos

# %%
ventas_nanitos = pd.read_csv('/content/drive/MyDrive/Maestria/Programación Python/Proyecto_PÁD/reporte_de_ventas_nanitos_may_a_jul_2026.csv', encoding='latin1', delimiter=';')

# %% [markdown]
# ##Validar carga de archivo y mostrar las primeras 5 filas

# %%
ventas_nanitos.head()
# Out:
#    Nro. factura      día                 fecha        Hora    Cajero  \
# 0         53257  viernes   31 de julio de 2026  8:06 p. m.  cajero 1
# 1         53256  viernes   31 de julio de 2026  7:59 p. m.  cajero 1
# 2         53255  viernes   31 de julio de 2026  7:57 p. m.  cajero 1
# 3         53255  viernes   31 de julio de 2026  7:57 p. m.  cajero 1
# 4         53254  viernes   31 de julio de 2026  7:55 p. m.  cajero 1
#
#     Vendedor  Nro. Documento           Cliente Medio de Pago Cod de Artículo  \
# 0  Vendedor              NaN  Ventas Mostrador      Efectivo            1420
# 1  Vendedor              NaN  Ventas Mostrador      Efectivo          3070-2
# 2  Vendedor              NaN  Ventas Mostrador      Efectivo          2080-1
# 3  Vendedor              NaN  Ventas Mostrador      Efectivo          1943-1
# 4  Vendedor              NaN  Ventas Mostrador      Efectivo          1998-1
#
#                      Producto Categoría  Vr.Costo  Vr.Unitario  \
# 0      MEDIAS ENCAJE MARATHON      ROPA      8500        14500
# 1      ROPA INTERIOR NIÑA X 3      ROPA      9000        17000
# 2        BODY BLANCO X UNIDAD      ROPA      5000        10000
# 3       BODY SUNNOZY X UNIDAD      ROPA     10125        17000
# 4  CONJUNTO DE LANA IMPORTADO      ROPA     55000        90000
#
#    Cantidad vendida  Total
# 0               1.0  14500
# 1               1.0  17000
# 2               1.0  10000
# 3               1.0  17000
# 4               1.0  90000
